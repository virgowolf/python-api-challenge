# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    try:
        # Group cities in sets of 50 for logging purposes
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 0

        # Create endpoint URL with each city
        response = requests.get(query_url + city).json()

        city_weather_dict = {
            "city": city,
            "latitude": response["coord"]["lat"],
            "longitude": response["coord"]["lon"],
            "max temp": response["main"]["temp_max"],
            "city humidity": response["main"]["humidity"],
            "cloudiness": response["clouds"]["all"],
            "wind speed": response["wind"]["speed"],
            "country": response["sys"]["country"],
            "date": response["dt"]
        }

        # Append city weather info to the city_data list
        city_data.append(city_weather_dict)

        # Log the processing of each city
        print(f"Processing Record {i+1} | {city}")

    except Exception as e:
        print(f"Error processing {city}: {e}")
        print("City not found. Skipping...")

# Convert the cities weather dictionary into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
print(city_data_df.count())
# Out:
# Error processing taiohae: 'coord'
# City not found. Skipping...
# Processing Record 2 | forster
# Processing Record 3 | blackmans bay
# Processing Record 4 | oak grove
# Processing Record 5 | grytviken
# Processing Record 6 | hamilton
# Processing Record 7 | tiksi
# Processing Record 8 | saint-leu
# Processing Record 9 | saldanha
# Processing Record 10 | fort bragg
# Processing Record 11 | san luis de la loma
# Processing Record 12 | praia da vitoria
# Processing Record 13 | al muwayh
# Processing Record 14 | antofagasta
# Processing Record 15 | georgetown
# Processing Record 16 | uturoa
# Processing Record 17 | avarua
# Processing Record 18 | lihue
# Processing Record 19 | bilibino
# Processing Record 20 | la'ie
# Processing Record 21 | la passe
# Processing Record 22 | owatonna
# Processing Record 23 | coari
# Processing Record 24 | ribeira grande
# Processing Record 25 | port saint john's
# Error processing cargados carajos: 'coord'
# City not found. Skipping...
# Processing Record 27 | kruisfontein
# Processing Record 28 | menzelinsk
# Processing Record 29 | bel ombre
# Processing Record 30 | yemva
# Processing Record 31 | an nimas
# Processing Record 32 | albany
# Processing Record 33 | qaqortoq
# Processing Record 34 | weno
# Processing Record 35 | jamestown
# Processing Record 36 | kirensk
# Error processing hayma': 'coord'
# City not found. Skipping...
# Processing Record 38 | cannonvale
# Processing Record 39 | edinburgh of the seven seas
# Processing Record 40 | guerrero negro
# Processing Record 41 | college
# Processing Record 42 | port-aux-francais
# Processing Record 43 | rabo de peixe
# Processing Record 44 | masterton
# Processing Record 45 | kingston
# Processing Record 46 | ilulissat
# Processing Record 47 | mocimboa
# Processing Record 48 | mount pearl
# Processing Record 49 | zouerate
# Processing Record 50 | dryden
# Error processing papatowai: name 'set_count' is not defined
# City not found. Skipping...
# Processing Record 52 | urangan
# Processing Record 53 | port mathurin
# Processing Record 54 | minas de marcona
# Error processing ayod: 'coord'
# City not found. Skipping...
# Processing Record 56 | invercargill
# Processing Record 57 | noyabrsk
# Processing Record 58 | gisborne
# Processing Record 59 | zalesovo
# Processing Record 60 | veraval
# Processing Record 61 | beau vallon
# Error processing puerto san carlos: 'coord'
# City not found. Skipping...
# Processing Record 63 | hilo
# Processing Record 64 | isafjordur
# Processing Record 65 | yellowknife
# Processing Record 66 | hermanus
# Processing Record 67 | waitangi
# Processing Record 68 | palu
# Processing Record 69 | iqaluit
# Processing Record 70 | kourou
# Processing Record 71 | vilyuchinsk
# Processing Record 72 | juneau
# Processing Record 73 | adamstown
# Processing Record 74 | anadyr
# Error processing dar naim: 'coord'
# City not found. Skipping...
# Processing Record 76 | villa bruzual
# Processing Record 77 | nikolayevsk-on-amure
# Processing Record 78 | fortuna
# Processing Record 79 | bethel
# Processing Record 80 | carnarvon
# Processing Record 81 | gora
# Processing Record 82 | puerto ayora
# Processing Record 83 | la ronge
# Processing Record 84 | filadelfia
# Processing Record 85 | margaret river
# Processing Record 86 | nabire
# Processing Record 87 | bargaal
# Processing Record 88 | nyaunglebin
# Processing Record 89 | longyearbyen
# Processing Record 90 | arraial do cabo
# Processing Record 91 | ushuaia
# Processing Record 92 | lebu
# Processing Record 93 | thompson
# Processing Record 94 | rongelap
# Processing Record 95 | sur
# Processing Record 96 | keflavik
# Processing Record 97 | chonchi
# Processing Record 98 | sungjibaegam
# Processing Record 99 | kailua-kona
# Processing Record 100 | greymouth
# Error processing nemuro: name 'set_count' is not defined
# City not found. Skipping...
# Error processing alotau: 'coord'
# City not found. Skipping...
# Processing Record 103 | kodinar
# Processing Record 104 | badger
# Processing Record 105 | chibougamau
# Processing Record 106 | whitehorse
# Processing Record 107 | howard springs
# Processing Record 108 | severo-yeniseyskiy
# Processing Record 109 | port elizabeth
# Processing Record 110 | shihezi
# Processing Record 111 | constantia
# Processing Record 112 | port macquarie
# Processing Record 113 | porto novo
# Processing Record 114 | hawaiian paradise park
# Processing Record 115 | stanley
# Processing Record 116 | karwar
# Processing Record 117 | northam
# Processing Record 118 | bredasdorp
# Processing Record 119 | saipan
# Processing Record 120 | happy valley-goose bay
# Processing Record 121 | lucea
# Error processing 'ohonua: 'coord'
# City not found. Skipping...
# Processing Record 123 | heihe
# Processing Record 124 | punta arenas
# Processing Record 125 | burnie
# Processing Record 126 | hadibu
# Processing Record 127 | utrik
# Processing Record 128 | west island
# Processing Record 129 | conception bay south
# Error processing espargos: 'coord'
# City not found. Skipping...
# Processing Record 131 | gouyave
# Processing Record 132 | belyy yar
# Processing Record 133 | burao
# Processing Record 134 | kodiak
# Processing Record 135 | mata-utu
# Processing Record 136 | yangjiang
# Processing Record 137 | wailua homesteads
# Processing Record 138 | tahlequah
# Processing Record 139 | st. john's
# Processing Record 140 | puerto natales
# Processing Record 141 | mounana
# Processing Record 142 | taksimo
# Error processing vohipaho: 'coord'
# City not found. Skipping...
# Error processing fuvahmulah: 'coord'
# City not found. Skipping...
# Processing Record 145 | cradock
# Processing Record 146 | ofunato
# Processing Record 147 | conde
# Processing Record 148 | bethanie
# Processing Record 149 | labytnangi
# Processing Record 150 | ballina
# Error processing tual: name 'set_count' is not defined
# City not found. Skipping...
# Processing Record 152 | santana
# Processing Record 153 | bosaso
# Processing Record 154 | sao vicente
# Processing Record 155 | malangali
# Processing Record 156 | san patricio
# Processing Record 157 | igrim
# Error processing san andros: 'coord'
# City not found. Skipping...
# Processing Record 159 | la foa
# Processing Record 160 | fale old settlement
# Processing Record 161 | senillosa
# Processing Record 162 | kotlas
# Error processing takamaka: 'coord'
# City not found. Skipping...
# Processing Record 164 | huarmey
# Processing Record 165 | karratha
# Processing Record 166 | iskateley
# Processing Record 167 | dudinka
# Processing Record 168 | kenai
# Processing Record 169 | olonkinbyen
# Processing Record 170 | ad darb
# Processing Record 171 | palmer
# Processing Record 172 | talnakh
# Processing Record 173 | luau
# Processing Record 174 | petropavlovsk-kamchatsky
# Processing Record 175 | grand-bassam
# Processing Record 176 | yelizovo
# Processing Record 177 | tralee
# Processing Record 178 | kupino
# Processing Record 179 | tolanaro
# Processing Record 180 | ouargla
# Processing Record 181 | ust-nera
# Processing Record 182 | balta
# Processing Record 183 | kalach
# Processing Record 184 | igarka
# Processing Record 185 | blackpool
# Processing Record 186 | port lincoln
# Processing Record 187 | aasiaat
# Processing Record 188 | sao joao da barra
# Processing Record 189 | morehead city
# Processing Record 190 | san clemente del tuyu
# Processing Record 191 | greenville
# Processing Record 192 | vila franca do campo
# Processing Record 193 | slonim
# Processing Record 194 | aykhal
# Processing Record 195 | ndola
# Processing Record 196 | cidreira
# Processing Record 197 | alice springs
# Processing Record 198 | lander
# Processing Record 199 | usogorsk
# Processing Record 200 | santa cruz
# Error processing tazovsky: name 'set_count' is not defined
# City not found. Skipping...
# Processing Record 202 | selfoss
# Processing Record 203 | remire-montjoly
# Error processing devinuwara: 'coord'
# City not found. Skipping...
# Processing Record 205 | vanimo
# Processing Record 206 | taroa
# Processing Record 207 | inhambane
# Processing Record 208 | xingtai
# Processing Record 209 | hwange
# Processing Record 210 | kapa'a
# Processing Record 211 | dortyol
# Processing Record 212 | sechura
# Processing Record 213 | prince albert
# Processing Record 214 | ust'-barguzin
# Processing Record 215 | gladstone
# Processing Record 216 | sao sebastiao
# Processing Record 217 | touros
# Processing Record 218 | atasu
# Processing Record 219 | lazaro cardenas
# Processing Record 220 | bonthe
# Processing Record 221 | akhaltsikhe
# Processing Record 222 | atafu village
# Error processing west busselton: 'coord'
# City not found. Skipping...
# Processing Record 224 | nguigmi
# Processing Record 225 | pimentel
# Processing Record 226 | udachny
# Processing Record 227 | ulladulla
# Processing Record 228 | aripuana
# Processing Record 229 | chalala
# Processing Record 230 | tadjourah
# Processing Record 231 | peace river
# Processing Record 232 | bardai
# Processing Record 233 | mungwi
# Processing Record 234 | tegueste
# Processing Record 235 | kapuskasing
# Processing Record 236 | maun
# Processing Record 237 | mezhdurechenskiy
# Processing Record 238 | acarau
# Processing Record 239 | tobelo
# Processing Record 240 | brades
# Processing Record 241 | mora
# Processing Record 242 | holalkere
# Processing Record 243 | bara
# Processing Record 244 | hithadhoo
# Processing Record 245 | al hazm
# Processing Record 246 | puerto baquerizo moreno
# Processing Record 247 | palikir - national government center
# Error processing whyalla stuart: 'coord'
# City not found. Skipping...
# Processing Record 249 | manavalakurichi
# Processing Record 250 | ulanhot
# Error processing kone: name 'set_count' is not defined
# City not found. Skipping...
# Processing Record 252 | arkhangel'sk
# Processing Record 253 | miyaly
# Processing Record 254 | kambove
# Processing Record 255 | zliten
# Processing Record 256 | suez
# Error processing tranovaho: 'coord'
# City not found. Skipping...
# Processing Record 258 | viedma
# Processing Record 259 | vorgashor
# Error processing vingt cinq: 'coord'
# City not found. Skipping...
# Processing Record 261 | totness
# Processing Record 262 | port alfred
# Processing Record 263 | tabou
# Processing Record 264 | villa emilio carranza
# Processing Record 265 | reggane
# Processing Record 266 | kattivakkam
# Processing Record 267 | tura
# Processing Record 268 | sabang
# Processing Record 269 | takoradi
# Processing Record 270 | kavalerovo
# Processing Record 271 | cozumel
# Processing Record 272 | puerto penasco
# Processing Record 273 | elverum
# Processing Record 274 | tazacorte
# Processing Record 275 | salahonda
# Processing Record 276 | bogande
# Processing Record 277 | vilhena
# Processing Record 278 | afaahiti
# Processing Record 279 | katerini
# Processing Record 280 | grand baie
# Processing Record 281 | bubaque
# Processing Record 282 | burang
# Processing Record 283 | gangneung
# Processing Record 284 | kavieng
# Processing Record 285 | pionerskiy
# Processing Record 286 | catalina
# Processing Record 287 | mugia
# Processing Record 288 | lerwick
# Processing Record 289 | ust'-ilimsk
# Processing Record 290 | redencao
# Processing Record 291 | verkhnevilyuysk
# Processing Record 292 | azna
# Processing Record 293 | el calafate
# Processing Record 294 | mount isa
# Processing Record 295 | ust-tsilma
# Processing Record 296 | rio gallegos
# Processing Record 297 | port blair
# Error processing bargara: 'coord'
# City not found. Skipping...
# Processing Record 299 | castillos
# Processing Record 300 | qingdao
# Error processing nova vicosa: name 'set_count' is not defined
# City not found. Skipping...
# Processing Record 302 | walvis bay
# Processing Record 303 | hammerfest
# Processing Record 304 | portland
# Processing Record 305 | embi
# Processing Record 306 | gaalkacyo
# Processing Record 307 | saint-pierre
# Processing Record 308 | kitui
# Processing Record 309 | chinsali
# Processing Record 310 | jaisalmer
# Processing Record 311 | brisas de zicatela
# Processing Record 312 | derbent
# Processing Record 313 | pasighat
# Processing Record 314 | merizo village
# Processing Record 315 | yuzhno-kurilsk
# Processing Record 316 | ntungamo
# Processing Record 317 | pitimbu
# Processing Record 318 | songyang
# Processing Record 319 | la paz
# Processing Record 320 | lively
# Processing Record 321 | sandnessjoen
# Processing Record 322 | bikenibeu village
# Processing Record 323 | grand rapids
# Processing Record 324 | cide
# Processing Record 325 | deqen
# Processing Record 326 | nuku'alofa
# Processing Record 327 | ploudalmezeau
# Processing Record 328 | san jose del guaviare
# Processing Record 329 | ciudad acuna
# Processing Record 330 | lata
# Processing Record 331 | ancud
# Processing Record 332 | calama
# Processing Record 333 | gadzhiyevo
# Processing Record 334 | kholmsk
# Processing Record 335 | haiku-pauwela
# Processing Record 336 | christchurch
# Processing Record 337 | new norfolk
# Processing Record 338 | roma
# Processing Record 339 | skeldon
# Processing Record 340 | horta
# Processing Record 341 | cole harbour
# Processing Record 342 | constantina
# Processing Record 343 | rikaze
# Processing Record 344 | turkmenbasy
# Processing Record 345 | gizo
# Processing Record 346 | vila velha
# Processing Record 347 | champerico
# Processing Record 348 | jaunpur
# Processing Record 349 | amga
# Processing Record 350 | buritis
# Error processing san andres: name 'set_count' is not defined
# City not found. Skipping...
# Processing Record 352 | phang nga
# Processing Record 353 | isola di capo rizzuto
# Processing Record 354 | el granada
# Processing Record 355 | turaif
# Processing Record 356 | thunder bay
# Processing Record 357 | achinsk
# Processing Record 358 | al ghayzah
# Processing Record 359 | al wajh
# Processing Record 360 | daniel flores
# Processing Record 361 | springbok
# Processing Record 362 | trincomalee
# Processing Record 363 | sisimiut
# Processing Record 364 | gamba
# Processing Record 365 | ouani
# Error processing qal'at bishah: 'coord'
# City not found. Skipping...
# Processing Record 367 | port alberni
# Processing Record 368 | aswan
# Processing Record 369 | mar del plata
# Error processing rukban: 'coord'
# City not found. Skipping...
# Processing Record 371 | suva
# Processing Record 372 | mogoytuy
# Processing Record 373 | dampit
# Processing Record 374 | nova sintra
# Processing Record 375 | amursk
# Processing Record 376 | talara
# Processing Record 377 | antalaha
# Processing Record 378 | santa rosa de osos
# Processing Record 379 | chos malal
# Processing Record 380 | klyuchi
# Processing Record 381 | alaghsas
# Processing Record 382 | nassau
# Processing Record 383 | amalapuram
# Processing Record 384 | pisco
# Processing Record 385 | martuk
# Processing Record 386 | xam nua
# Processing Record 387 | maumere
# Processing Record 388 | enewetak
# Processing Record 389 | turinsk
# Processing Record 390 | kachkanar
# Processing Record 391 | t'ongch'on-up
# Processing Record 392 | maputo
# Processing Record 393 | namibe
# Processing Record 394 | montgomery
# Processing Record 395 | at taj
# Processing Record 396 | tingo maria
# Processing Record 397 | alofi
# Processing Record 398 | taro
# Processing Record 399 | toledo
# Processing Record 400 | puerto madero
# Error processing la mira: name 'set_count' is not defined
# City not found. Skipping...
# Processing Record 402 | zeya
# Processing Record 403 | coahuayana de hidalgo
# Processing Record 404 | hotan
# Processing Record 405 | flying fish cove
# Processing Record 406 | feijo
# Processing Record 407 | vadso
# Processing Record 408 | galliano
# Processing Record 409 | naze
# Processing Record 410 | amahai
# Processing Record 411 | saint-joseph
# Processing Record 412 | kuta
# Processing Record 413 | sungai raya
# Processing Record 414 | nantucket
# Processing Record 415 | broken hill
# Processing Record 416 | la manga del mar menor
# Processing Record 417 | yashkul'
# Processing Record 418 | chenzhou
# Processing Record 419 | gubkinskiy
# Processing Record 420 | poronaysk
# Processing Record 421 | den helder
# Processing Record 422 | ponta delgada
# Processing Record 423 | howrah
# Processing Record 424 | arti
# Processing Record 425 | nuuk
# Processing Record 426 | pindushi
# Processing Record 427 | port hedland
# Processing Record 428 | sealy
# Processing Record 429 | staryye ozinki
# Processing Record 430 | garh maharaja
# Processing Record 431 | camalu
# Processing Record 432 | yorkton
# Processing Record 433 | morondava
# Processing Record 434 | dunedin
# Processing Record 435 | itaituba
# Processing Record 436 | gornyy
# Processing Record 437 | bodo
# Processing Record 438 | lompoc
# Processing Record 439 | centralia
# Processing Record 440 | rurrenabaque
# Processing Record 441 | sitka
# Processing Record 442 | chapaev
# Processing Record 443 | hailin
# Processing Record 444 | holualoa
# Processing Record 445 | dwarka
# Error processing koynanagar: 'coord'
# City not found. Skipping...
# Processing Record 447 | ak-suu
# Processing Record 448 | al jawf
# Processing Record 449 | as sulayyil
# Processing Record 450 | luebo
# Error processing alta: name 'set_count' is not defined
# City not found. Skipping...
# Processing Record 452 | armacao de buzios
# Processing Record 453 | egilsstadir
# Processing Record 454 | bodaybo
# Processing Record 455 | byron bay
# Processing Record 456 | quellon
# Processing Record 457 | carloforte
# Processing Record 458 | puerto deseado
# Processing Record 459 | ugoofaaru
# Processing Record 460 | weihai
# Error processing kulia village: 'coord'
# City not found. Skipping...
# Processing Record 462 | bechar
# Processing Record 463 | kidal
# Processing Record 464 | iglino
# Processing Record 465 | north battleford
# Processing Record 466 | hobyo
# Processing Record 467 | pacific grove
# Processing Record 468 | nkhotakota
# Processing Record 469 | teluk nibung
# Processing Record 470 | novobelokatay
# Processing Record 471 | chulym
# Processing Record 472 | nelson bay
# Processing Record 473 | mukalla
# Processing Record 474 | abeche
# Processing Record 475 | kununurra
# Processing Record 476 | san antonio de pale
# Processing Record 477 | dire
# Processing Record 478 | alesund
# Processing Record 479 | garoowe
# Processing Record 480 | spanish wells
# Processing Record 481 | tromso
# Processing Record 482 | salinopolis
# Processing Record 483 | arteche
# Processing Record 484 | jaleshwar
# Processing Record 485 | usinsk
# Processing Record 486 | 'alaqahdari dishu
# Processing Record 487 | pagar alam
# Processing Record 488 | okhotsk
# Processing Record 489 | santa elena de uairen
# Processing Record 490 | freetown
# Processing Record 491 | tyukhtet
# Error processing hawsh 'isa: 'coord'
# City not found. Skipping...
# Processing Record 493 | dul'durga
# Processing Record 494 | madang
# Processing Record 495 | ta`u
# Processing Record 496 | tamanrasset
# Processing Record 497 | kuqa
# Processing Record 498 | makungu
# Processing Record 499 | kargasok
# Processing Record 500 | east london
# Error processing hanceville: name 'set_count' is not defined
# City not found. Skipping...
# Error processing ahau: 'coord'
# City not found. Skipping...
# Processing Record 503 | saint-felicien
# Processing Record 504 | mount gambier
# Processing Record 505 | lospalos
# Processing Record 506 | porto seguro
# Processing Record 507 | corn island
# Processing Record 508 | awjilah
# Processing Record 509 | grosseto
# Processing Record 510 | rudbar
# Processing Record 511 | codrington
# Processing Record 512 | pacasmayo
# Processing Record 513 | nosy varika
# Error processing benito garcia (el zorrillo): 'coord'
# City not found. Skipping...
# Processing Record 515 | menongue
# Processing Record 516 | dongcun
# Processing Record 517 | lorengau
# Processing Record 518 | hrib-loski potok
# Processing Record 519 | kalamansig
# Processing Record 520 | abilene
# Processing Record 521 | sungailiat
# Processing Record 522 | richards bay
# Processing Record 523 | qamdo
# Processing Record 524 | erdenet
# Processing Record 525 | fort mcmurray
# Processing Record 526 | kodinsk
# Processing Record 527 | princeville
# Processing Record 528 | port antonio
# Processing Record 529 | las khorey
# Processing Record 530 | formosa do rio preto
# Processing Record 531 | baykal'sk
# Processing Record 532 | pangody
# Processing Record 533 | neiafu
# Processing Record 534 | cill airne
# Processing Record 535 | fyodorovka
# Processing Record 536 | crane
# Processing Record 537 | booue
# Processing Record 538 | malkerns
# Processing Record 539 | jashpurnagar
# Processing Record 540 | nieuw amsterdam
# Processing Record 541 | luanco
# Processing Record 542 | box elder
# Processing Record 543 | tsiombe
# Processing Record 544 | jaru
# Processing Record 545 | quarai
# Processing Record 546 | kralendijk
# Processing Record 547 | goldap
# Processing Record 548 | barrouallie
# Processing Record 549 | rouissat
# Processing Record 550 | hastings
# Error processing zapata: name 'set_count' is not defined
# City not found. Skipping...
# Error processing setti fatma: 'coord'
# City not found. Skipping...
# Processing Record 553 | durgapur
# Processing Record 554 | tarumovka
# Processing Record 555 | oranjemund
# Processing Record 556 | chasong
# Processing Record 557 | mangrol
# Processing Record 558 | krasnyy chikoy
# Processing Record 559 | la voulte-sur-rhone
# Processing Record 560 | floro
# Processing Record 561 | coaticook
# Processing Record 562 | nizhneangarsk
# Processing Record 563 | homer
# Processing Record 564 | griffith
# Processing Record 565 | orsa
# Processing Record 566 | cabo san lucas
# Processing Record 567 | as sanamayn
# Processing Record 568 | keetmanshoop
# Processing Record 569 | yatou
# Processing Record 570 | aldan
# Processing Record 571 | ahus
# Processing Record 572 | sangueya
# Processing Record 573 | spring creek
# Processing Record 574 | peruibe
# Processing Record 575 | erie
# Error processing g'ijduvon shahri: 'coord'
# City not found. Skipping...
# Processing Record 577 | carnota
# Processing Record 578 | ciudad lazaro cardenas
# Processing Record 579 | nouadhibou
# Processing Record 580 | flekkefjord
# Error processing ayaguz: 'coord'
# City not found. Skipping...
# Processing Record 582 | coquimbo
# Processing Record 583 | pizarro
# Processing Record 584 | taroudant
# Processing Record 585 | sao jose da coroa grande
# Processing Record 586 | tianchang
# Processing Record 587 | corral de bustos
# Processing Record 588 | nanlong
# Processing Record 589 | madimba
# Processing Record 590 | dori
# Processing Record 591 | intibuca
# Processing Record 592 | luganville
# Processing Record 593 | monrovia
# Processing Record 594 | hasaki
# Processing Record 595 | inirida
# Processing Record 596 | saint-philippe
# city             556
# latitude         556
# longitude        556
# max temp         556
# city humidity    556
# cloudiness       556
# wind speed       556
# country          556
# date             556
# dtype: int64

# %%
# Log the processing of each city
print(f"Processing Record {i+1} | {city}")

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Processing Record 596 | saint-philippe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Display sample data
city_data_df
# Out:
#                city  latitude  longitude  max temp  city humidity  cloudiness  \
# 0           forster  -32.1667   152.5167     81.37             58          20
# 1     blackmans bay  -43.0167   147.3167     63.52             69          74
# 2         oak grove   45.4168  -122.6401     48.94             89         100
# 3         grytviken  -54.2811   -36.5092     42.31             81          43
# 4          hamilton   39.1834   -84.5333     56.25             37           0
# ..              ...       ...        ...       ...            ...         ...
# 551      luganville  -15.5333   167.1667     85.53             75         100
# 552        monrovia    6.3005   -10.7969     78.57             91          43
# 553          hasaki   35.7333   140.8333     48.60             58         100
# 554         inirida    3.8653   -67.9239     78.01             87         100
# 555  saint-philippe  -21.3585    55.7679     76.59             88          23
#
#      wind speed country        date
# 0          5.66      AU  1710200888
# 1          1.99      AU  1710200888
# 2          9.22      US  1710200350
# 3          7.70      GS  1710200888
# 4         12.66      US  1710200889
# ..          ...     ...         ...
# 551        2.48      VU  1710201154
# 552        2.35      LR  1710201154
# 553       19.44      JP  1710201155
# 554        2.04      CO  1710201155
# 555       12.68      RE  1710201155
#
# [556 rows x 9 columns]

# %%
import os

# Define the directory path
output_dir = "Resources/output_data"

# Save the DataFrame to a CSV file
city_data_df.to_csv(os.path.join(output_dir, "my_cities.csv"), index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/my_cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Read saved data
# ----> 2 city_data_df = pd.read_csv("output_data/my_cities.csv", index_col="City_ID")
#       4 # Display sample data
#       5 city_data_df.head()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/my_cities.csv'

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
